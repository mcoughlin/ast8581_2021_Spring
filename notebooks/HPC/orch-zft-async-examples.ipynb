# %% [markdown]
# # ZTF single day file exploration with Async, Promises and Orchestrator

# %%
import orchestrator as orch
import time
import sys
import tarfile
import os
import functools

from pprint import pprint
from promise import Promise

from fastavro import reader, writer
import julian

# %%
ztf_file="data/ztf_public_20190728.tar.gz"
ztf_date="20190728"

# %%
# untar the file
untar_file = False

if untar_file:
    print("extracting alerts from %s" % ztf_file)
    tar = tarfile.open(ztf_file)
    tar.extractall(path="in/%s" % ztf_date)
    tar.close()
else:
    print("skipping file extraction")
    if not os.path.exists("in/%s" % ztf_date):
        raise(RuntimeError("ZTF alerts directory %s does not exists"))
    else:
        print("Using in/%s as ZTF alert directory" % ztf_date)

ztf_in="in/%s" % ztf_date
# Out:
# skipping file extraction
# Using in/20190728 as ZTF alert directory

# %%
# count the alerts in the directory

num_alerts=0

avro_files = []
avro_limit = 10000

for file in os.listdir(ztf_in):
    if file.endswith(".avro"):
        num_alerts+=1
        if num_alerts < avro_limit:
            avro_files.append(file)

print("num alerts: %d" % num_alerts)
# Out:
# num alerts: 125586

# %%
file = "938318155215010004.avro"

with open("%s/%s" % (ztf_in,file), 'rb') as fo:
    avro_reader = reader(fo)
    for record in avro_reader:
        pprint(record)
# Out:
# {'candid': 938318155215010004,
#  'candidate': {'aimage': 0.7630000114440918,
#                'aimagerat': 0.27745455503463745,
#                'bimage': 0.7200000286102295,
#                'bimagerat': 0.26181817054748535,
#                'candid': 938318155215010004,
#                'chinr': 1.3009999990463257,
#                'chipsf': 37.39431381225586,
#                'classtar': 0.9829999804496765,
#                'clrcoeff': 0.08901599794626236,
#                'clrcounc': 9.455599865759723e-06,
#                'clrmed': 0.9570000171661377,
#                'clrrms': 0.27230900526046753,
#                'dec': 22.6338266,
#                'decnr': 22.6338191,
#                'diffmaglim': 20.799943923950195,
#                'distnr': 0.042584728449583054,
#                'distpsnr1': 0.06271562725305557,
#                'distpsnr2': 0.2556854486465454,
#                'distpsnr3': 2.1249427795410156,
#                'drb': 0.9395135641098022,
#                'drbversion': 'd6_m7',
#                'dsdiff': -152.47169494628906,
#                'dsnrms': 194.2211456298828,
#                'elong': 1.0597221851348877,
#                'exptime': 30.0,
#                'fid': 2,
#                'field': 591,
#                'fwhm': 2.75,
#                'isdiffpos': 'f',
#                'jd': 2458692.8181597,
#                'jdendhist': 2458692.8186111,
#                'jdendref': 2458294.833785,
#                'jdstarthist': 2458291.9795139,
#                'jdstartref': 2458217.987905,
#                'magap': 16.78219985961914,
#                'magapbig': 16.776399612426758,
#                'magdiff': 0.05787000060081482,
#                'magfromlim': 4.017744064331055,
#                'maggaia': 20.056299209594727,
#                'maggaiabright': 13.670029640197754,
#                'magnr': 15.411999702453613,
#                'magpsf': 16.72433090209961,
#                'magzpsci': 26.22732925415039,
#                'magzpscirms': 0.039834000170230865,
#                'magzpsciunc': 1.1028900189558044e-05,
#                'mindtoedge': 104.77189636230469,
#                'nbad': 0,
#                'ncovhist': 1141,
#                'ndethist': 359,
#                'neargaia': 7.340592384338379,
#                'neargaiabright': 72.6349105834961,
#                'nframesref': 30,
#                'nid': 938,
#                'nmatches': 1425,
#                'nmtchps': 105,
#                'nneg': 1,
#                'objectidps1': 135162973476221061,
#                'objectidps2': 135162973472471078,
#                'objectidps3': 135162973470710575,
#                'pdiffimfilename': 'ztf_20190728318160_000591_zr_c14_o_q1_scimrefdiffimg.fits',
#                'pid': 938318155215,
#                'programid': 1,
#                'programpi': 'TESS',
#                'ra': 297.3474293,
#                'ranr': 297.3474176,
#                'rb': 0.7599999904632568,
#                'rbversion': 't17_f5_c3',
#                'rcid': 52,
#                'rfid': 591120252,
#                'scorr': 13.8563222885132,
#                'seeratio': 0.9055853486061096,
#                'sgmag1': -999.0,
#                'sgmag2': 18.63680076599121,
#                'sgmag3': -999.0,
#                'sgscore1': 0.5,
#                'sgscore2': 0.9485769867897034,
#                'sgscore3': 0.5,
#                'sharpnr': 0.1120000034570694,
#                'sigmagap': 0.014499999582767487,
#                'sigmagapbig': 0.01640000008046627,
#                'sigmagnr': 0.027000000700354576,
#                'sigmapsf': 0.0860411748290062,
#                'simag1': 13.288000106811523,
#                'simag2': 12.071000099182129,
#                'simag3': -999.0,
#                'sky': -3.467283010482788,
#                'srmag1': 14.49839973449707,
#                'srmag2': 15.896900177001953,
#                'srmag3': -999.0,
#                'ssdistnr': -999.0,
#                'ssmagnr': -999.0,
#                'ssnamenr': 'null',
#                'ssnrms': 346.6928405761719,
#                'sumrat': 1.0,
#                'szmag1': -999.0,
#                'szmag2': 10.621000289916992,
#                'szmag3': 14.715900421142578,
#                'tblid': 4,
#                'tooflag': 0,
#                'xpos': 2469.870849609375,
#                'ypos': 104.77189636230469,
#                'zpclrcov': -9.88000010693213e-06,
#                'zpmed': 26.319000244140625},
#  'cutoutDifference': {'fileName': 'candid938318155215010004_pid938318155215_targ_refmsci.fits.gz',
#                       'stampData': b'\x1f\x8b\x08\x00?[=]\x02\x03\xed\xb7'
#                                    b'iX\x8f_\xf8\xf6K\x9ag\x1aD\x9a4\x18R\x14'
#                                    b'\x15\xa9{\xado\x89J*B$E\x99g\x12\x99\x9b'
#                                    b'%\x95\xe6y\x12E\x92B\x03\xaa\xef:'
#                                    b'\xef\x06\x99"27\xa0P\xc8T\xa6d'
#                                    b'\xd8\x8eg\xbf\xdb\xc7\xf3f?\xfb\x7f\xec'
#                                    b'W\xbf\xcf\xcb\xfb\xc5y\xac{]\xd7y'
#                                    b'\xad\xebts\x98\xe7\xead\xa7\xadm\xad'
#                                    b'\xad\xbdP\xfb\x7f\x00\x1b\x87\x85\xae\x0eK'
#                                    b'\xfe\x97\xde\xff\x13\xa3\xa9\xa6'
#                                    b'\xff\xef\xf5\x9c\x05K\x1c\xdc\xb4\xff\xb7z'
#                                    b'\xda\xda\xff\xa7z&\xff{=\xf3\xa9\xff'
#                                    b'\x87z\xa6\xffsz6\x8b\x9c\x1d\x16\xfe'
#                                    b'\xaf\xff\x1d7\xcb\xf9\xff\xfe4\xee\xffK'
#                                    b'=\xec\x9cgi\xff\xc7\x7f\xfc\xc7\x7f\xfc'
#                                    b'\x979\xcau\xc1`\xec9\x04\x8c\x92\xa1'
#                                    b'\xf2\x8d\x84=\xff:\x13\xe7K\x1c\x85\x99'
#                                    b'\xa7c\x85?[O\xd0\x0f\xd2\xc5\xcc\xee'
#                                    b'\xd9\x01d\xea\xe4\x80\xcd\xc8\x80\x82\xe3P'
#                                    b'^.\xe1\x1b\x0e\xdc~\x84\x11S\xce\xb0'
#                                    b'\x11\xf3\xaaXzT\x17\xfb\xd0\x7f\x86\xec'
#                                    b'8\xfe\x17\xb7\xef\x8c\xc2\x9f'
#                                    b'\xf3\xeb\xe8\xc8[\x84\xfa~\xad!-\x87'
#                                    b'S\xe9\xfc\xef\x834\xf0\xdc\x0f\x1cM['
#                                    b'Mc\x17\xbe\xa3^w=\xd9\xf2K\x15'
#                                    b'\xe4z\xac\x0f/\x11\xdb\x82\x97\xb3&\x13'
# ...
#                      'candid': 936338205215010001,
#                      'chinr': 1.3009999990463257,
#                      'chipsf': 35.231300354003906,
#                      'classtar': 0.9990000128746033,
#                      'clrcoeff': 0.0822833999991417,
#                      'clrcounc': 3.809160034506931e-06,
#                      'dec': 22.6338248,
#                      'decnr': 22.6338191,
#                      'diffmaglim': 20.864500045776367,
#                      'distnr': 0.05689899995923042,
#                      'elong': 1.0359699726104736,
#                      'fid': 2,
#                      'field': 591,
#                      'fwhm': 3.009999990463257,
#                      'isdiffpos': 'f',
#                      'jd': 2458690.838206,
#                      'magap': 16.83009910583496,
#                      'magapbig': 16.837600708007812,
#                      'magdiff': 0.0847650021314621,
#                      'magfromlim': 4.034420013427734,
#                      'magnr': 15.411999702453613,
#                      'magpsf': 16.74530029296875,
#                      'magzpsci': 26.194299697875977,
#                      'magzpscirms': 0.020177900791168213,
#                      'magzpsciunc': 4.456060196389444e-06,
#                      'mindtoedge': 108.71099853515625,
#                      'nbad': 0,
#                      'nid': 936,
#                      'nneg': 3,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0726/338206/ztf_20190726338206_000591_zr_c14_o_q1_scimrefdiffimg.fits.fz',
#                      'pid': 936338205215,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': 297.3474383,
#                      'ranr': 297.3474176,
#                      'rb': 0.7342860102653503,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 52,
#                      'scorr': 17.1286,
#                      'seeratio': 0.8282039761543274,
#                      'sharpnr': 0.1120000034570694,
#                      'sigmagap': 0.01489999983459711,
#                      'sigmagapbig': 0.016899999231100082,
#                      'sigmagnr': 0.027000000700354576,
#                      'sigmapsf': 0.0614750012755394,
#                      'sky': -5.2032599449157715,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': 0.9998459815979004,
#                      'tblid': 1,
#                      'xpos': 2480.18994140625,
#                      'ypos': 108.71099853515625},
#                     {'aimage': 0.6129999756813049,
#                      'aimagerat': 0.5080639719963074,
#                      'bimage': 0.5759999752044678,
#                      'bimagerat': 0.47739800810813904,
#                      'candid': 936338651415010093,
#                      'chinr': 1.2139999866485596,
#                      'chipsf': 98.90299987792969,
#                      'classtar': 0.996999979019165,
#                      'clrcoeff': 0.11372900009155273,
#                      'clrcounc': 9.15217970032245e-06,
#                      'dec': 22.6338583,
#                      'decnr': 22.6338067,
#                      'diffmaglim': 20.591899871826172,
#                      'distnr': 0.18255600333213806,
#                      'elong': 1.0642399787902832,
#                      'fid': 2,
#                      'field': 640,
#                      'fwhm': 1.2065399885177612,
#                      'isdiffpos': 'f',
#                      'jd': 2458690.8386574,
#                      'magap': 16.9335994720459,
#                      'magapbig': 16.93869972229004,
#                      'magdiff': 0.1023939996957779,
#                      'magfromlim': 3.6582798957824707,
#                      'magnr': 15.388999938964844,
#                      'magpsf': 16.831199645996094,
#                      'magzpsci': 25.989200592041016,
#                      'magzpscirms': 0.029913799837231636,
#                      'magzpsciunc': 9.579440302331932e-06,
#                      'mindtoedge': 971.0540161132812,
#                      'nbad': 0,
#                      'nid': 936,
#                      'nneg': 3,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0726/338657/ztf_20190726338657_000640_zr_c04_o_q3_scimrefdiffimg.fits.fz',
#                      'pid': 936338651415,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': 297.3473623,
#                      'ranr': 297.3473782,
#                      'rb': 0.6814290285110474,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 14,
#                      'scorr': 12.5697,
#                      'seeratio': 2.0,
#                      'sharpnr': -0.017000000923871994,
#                      'sigmagap': 0.01979999989271164,
#                      'sigmagapbig': 0.02290000021457672,
#                      'sigmagnr': 0.02800000086426735,
#                      'sigmapsf': 0.10150399804115295,
#                      'sky': -3.213710069656372,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': 1.0,
#                      'tblid': 93,
#                      'xpos': 1364.4300537109375,
#                      'ypos': 2109.449951171875},
#                     {'aimage': 0.7009999752044678,
#                      'aimagerat': 0.2982980012893677,
#                      'bimage': 0.5830000042915344,
#                      'bimagerat': 0.24808500707149506,
#                      'candid': 937314901415010055,
#                      'chinr': 0.9020000100135803,
#                      'chipsf': 2.02305006980896,
#                      'classtar': 0.9509999752044678,
#                      'clrcoeff': -0.06581869721412659,
#                      'clrcounc': 5.164480171515606e-06,
#                      'dec': 22.6337712,
#                      'decnr': 22.633811,
#                      'diffmaglim': 20.798799514770508,
#                      'distnr': 0.19506500661373138,
#                      'elong': 1.2023999691009521,
#                      'fid': 1,
#                      'field': 640,
#                      'fwhm': 2.3499999046325684,
#                      'isdiffpos': 'f',
#                      'jd': 2458691.8149074,
#                      'magap': 19.912599563598633,
#                      'magapbig': 19.942800521850586,
#                      'magdiff': -0.07827500253915787,
#                      'magfromlim': 0.8861849904060364,
#                      'magnr': 18.617000579833984,
#                      'magpsf': 19.99090003967285,
#                      'magzpsci': 26.083900451660156,
#                      'magzpscirms': 0.022458499297499657,
#                      'magzpsciunc': 5.414729912445182e-06,
#                      'mindtoedge': 977.8980102539062,
#                      'nbad': 0,
#                      'nid': 937,
#                      'nneg': 10,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0727/314873/ztf_20190727314873_000640_zg_c04_o_q3_scimrefdiffimg.fits.fz',
#                      'pid': 937314901415,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': 297.3474442,
#                      'ranr': 297.3474033,
#                      'rb': 0.807142972946167,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 14,
#                      'scorr': 7.36339,
#                      'seeratio': 1.096850037574768,
#                      'sharpnr': 0.08100000023841858,
#                      'sigmagap': 0.17270000278949738,
#                      'sigmagapbig': 0.2248000055551529,
#                      'sigmagnr': 0.02199999988079071,
#                      'sigmapsf': 0.20556899905204773,
#                      'sky': -0.8745970129966736,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': 0.8268479704856873,
#                      'tblid': 55,
#                      'xpos': 1337.52001953125,
#                      'ypos': 2102.60009765625},
#                     {'aimage': None,
#                      'aimagerat': None,
#                      'bimage': None,
#                      'bimagerat': None,
#                      'candid': None,
#                      'chinr': None,
#                      'chipsf': None,
#                      'classtar': None,
#                      'clrcoeff': -0.05909249931573868,
#                      'clrcounc': 3.961079983128002e-06,
#                      'dec': None,
#                      'decnr': None,
#                      'diffmaglim': 20.912900924682617,
#                      'distnr': None,
#                      'elong': None,
#                      'fid': 1,
#                      'field': 591,
#                      'fwhm': None,
#                      'isdiffpos': None,
#                      'jd': 2458691.8153588,
#                      'magap': None,
#                      'magapbig': None,
#                      'magdiff': None,
#                      'magfromlim': None,
#                      'magnr': None,
#                      'magpsf': None,
#                      'magzpsci': 26.231599807739258,
#                      'magzpscirms': 0.020535500720143318,
#                      'magzpsciunc': 4.62317984784022e-06,
#                      'mindtoedge': None,
#                      'nbad': None,
#                      'nid': 937,
#                      'nneg': None,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0727/315347/ztf_20190727315347_000591_zg_c14_o_q1_scimrefdiffimg.fits.fz',
#                      'pid': 937315355215,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': None,
#                      'ranr': None,
#                      'rb': None,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 52,
#                      'scorr': None,
#                      'seeratio': None,
#                      'sharpnr': None,
#                      'sigmagap': None,
#                      'sigmagapbig': None,
#                      'sigmagnr': None,
#                      'sigmapsf': None,
#                      'sky': None,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': None,
#                      'tblid': None,
#                      'xpos': None,
#                      'ypos': None},
#                     {'aimage': 0.6620000004768372,
#                      'aimagerat': 0.1854339987039566,
#                      'bimage': 0.628000020980835,
#                      'bimagerat': 0.17590999603271484,
#                      'candid': 937358325215010010,
#                      'chinr': 1.3009999990463257,
#                      'chipsf': 87.42729949951172,
#                      'classtar': 1.0,
#                      'clrcoeff': 0.08546850085258484,
#                      'clrcounc': 5.222269919613609e-06,
#                      'dec': 22.6338315,
#                      'decnr': 22.6338191,
#                      'diffmaglim': 20.867000579833984,
#                      'distnr': 0.048385001718997955,
#                      'elong': 1.0541399717330933,
#                      'fid': 2,
#                      'field': 591,
#                      'fwhm': 3.569999933242798,
#                      'isdiffpos': 'f',
#                      'jd': 2458691.8583218,
#                      'magap': 16.791400909423828,
#                      'magapbig': 16.799299240112305,
#                      'magdiff': 0.12883099913597107,
#                      'magfromlim': 4.075650215148926,
#                      'magnr': 15.411999702453613,
#                      'magpsf': 16.662599563598633,
#                      'magzpsci': 26.224599838256836,
#                      'magzpscirms': 0.02348089963197708,
#                      'magzpsciunc': 6.092569947213633e-06,
#                      'mindtoedge': 103.5270004272461,
#                      'nbad': 0,
#                      'nid': 937,
#                      'nneg': 2,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0727/358310/ztf_20190727358310_000591_zr_c14_o_q1_scimrefdiffimg.fits.fz',
#                      'pid': 937358325215,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': 297.347426,
#                      'ranr': 297.3474176,
#                      'rb': 0.7400000095367432,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 52,
#                      'scorr': 35.8161,
#                      'seeratio': 0.6968690156936646,
#                      'sharpnr': 0.1120000034570694,
#                      'sigmagap': 0.0142000000923872,
#                      'sigmagapbig': 0.016200000420212746,
#                      'sigmagnr': 0.027000000700354576,
#                      'sigmapsf': 0.10821399837732315,
#                      'sky': -4.733349800109863,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': 0.9995729923248291,
#                      'tblid': 10,
#                      'xpos': 2456.7099609375,
#                      'ypos': 103.5270004272461},
#                     {'aimage': 0.734000027179718,
#                      'aimagerat': 0.5986890196800232,
#                      'bimage': 0.6520000100135803,
#                      'bimagerat': 0.5318049788475037,
#                      'candid': 937359681415010069,
#                      'chinr': 1.2139999866485596,
#                      'chipsf': 28.715099334716797,
#                      'classtar': 0.9010000228881836,
#                      'clrcoeff': 0.09738309681415558,
#                      'clrcounc': 3.8024800232960843e-06,
#                      'dec': 22.6337932,
#                      'decnr': 22.6338067,
#                      'diffmaglim': 20.496000289916992,
#                      'distnr': 0.04971399903297424,
#                      'elong': 1.1257699728012085,
#                      'fid': 2,
#                      'field': 640,
#                      'fwhm': 1.2260099649429321,
#                      'isdiffpos': 'f',
#                      'jd': 2458691.8596875,
#                      'magap': 16.97640037536621,
#                      'magapbig': 16.969900131225586,
#                      'magdiff': -0.024661000818014145,
#                      'magfromlim': 3.519629955291748,
#                      'magnr': 15.388999938964844,
#                      'magpsf': 17.001100540161133,
#                      'magzpsci': 26.063100814819336,
#                      'magzpscirms': 0.019270800054073334,
#                      'magzpsciunc': 3.986850060755387e-06,
#                      'mindtoedge': 975.3410034179688,
#                      'nbad': 0,
#                      'nid': 937,
#                      'nneg': 3,
#                      'pdiffimfilename': '/ztf/archive/sci/2019/0727/359676/ztf_20190727359676_000640_zr_c04_o_q3_scimrefdiffimg.fits.fz',
#                      'pid': 937359681415,
#                      'programid': 1,
#                      'programpi': 'TESS',
#                      'ra': 297.3473768,
#                      'ranr': 297.3473782,
#                      'rb': 0.7342860102653503,
#                      'rbversion': 't17_f5_c3',
#                      'rcid': 14,
#                      'scorr': 6.19102,
#                      'seeratio': 2.0,
#                      'sharpnr': -0.017000000923871994,
#                      'sigmagap': 0.02070000022649765,
#                      'sigmagapbig': 0.02410000003874302,
#                      'sigmagnr': 0.02800000086426735,
#                      'sigmapsf': 0.0636110007762909,
#                      'sky': -2.0720300674438477,
#                      'ssdistnr': None,
#                      'ssmagnr': None,
#                      'ssnamenr': None,
#                      'sumrat': 1.0,
#                      'tblid': 69,
#                      'xpos': 1341.719970703125,
#                      'ypos': 2105.159912109375}],
#  'publisher': 'ZTF (www.ztf.caltech.edu)',
#  'schemavsn': '3.3'}

# %%
# get the date distribution

dates={}

log_each    = 1000
num_records = 0

for file in avro_files:
    with open("%s/%s" % (ztf_in,file), 'rb') as fo:
        avro_reader = reader(fo)
        for record in avro_reader:
            #pprint(record)
            num_records+=1
            jd = record["candidate"]["jd"]
            ts = julian.from_jd(jd, fmt='jd')
            ts_key = ts.strftime("%Y%m%d")
            if ts_key in dates:
                dates[ts_key]+=1
            else:
                dates[ts_key]=1

        if (num_records % log_each) == 0:
            print("%.2f %% completed" % ((num_records/avro_limit) * 100))

print(dates)
# Out:
# 10.00 % completed
# 20.00 % completed
# 30.00 % completed
# 40.00 % completed
# 50.00 % completed
# 60.00 % completed
# 70.00 % completed
# 80.00 % completed
# 90.00 % completed
# {'20190728': 9999}

# %% [markdown]
# ## Too slow?? check the ipython_kernel process and explain what do you see

# %%
# using only asyncronous call and list comprehensions

dates={}

log_each    = 1000

class Counter:
    def __init__(self,count=0,log_each=100,total = 0):
        self.count    = count
        self.log_each = log_each
        self.total    = total
    def add(self, c):
        self.count+=c
    def show_completed(self):
        if (self.count % self.log_each) == 0:
            print("%.2f %% completed" % ((self.count/self.total) * 100))
    def __repr__(self):
        return self.count

@orch.Async
def map_ts_key(file, counter):
    num_records = 0
    with open("%s/%s" % (ztf_in,file), 'rb') as fo:
        avro_reader = reader(fo)
        for record in avro_reader:
            #pprint(record)
            num_records+=1
            jd = record["candidate"]["jd"]
            ts = julian.from_jd(jd, fmt='jd')
            ts_key = ts.strftime("%Y%m%d")
            if ts_key in dates:
                dates[ts_key]+=1
            else:
                dates[ts_key]=1
                
    counter.add(num_records)
    counter.show_completed()
    
counter = Counter(0,log_each, len(avro_files))
counts = [ map_ts_key(x,counter) for x in avro_files ]

for x in counts:
    x.wait()
print(dates)
# Out:
# 10.00 % completed
# 20.00 % completed
# 30.00 % completed
# 40.00 % completed
# 50.01 % completed
# 60.01 % completed
# 70.01 % completed
# 80.01 % completed
# 90.01 % completed
# {'20190728': 9999}

# %% [markdown]
# ## a bit better ? let's try to push a bit more the performance

# %%
# rebuild the list?
rebuild_avro_list = False
if rebuild_avro_list:
    num_alerts=0

    avro_files = []
    avro_limit = 100000

    for file in os.listdir(ztf_in):
        if file.endswith(".avro"):
            num_alerts+=1
            if num_alerts < avro_limit:
                avro_files.append(file)

    print("num alerts: %d" % num_alerts)

number_of_chunks = 10

chunk_size = int(len(avro_files)/number_of_chunks)+1
print("chunk_size: ",chunk_size)

log_each    = 1000

chunks = lambda l, n: [l[x: x+n] for x in range(0, len(l), n)]
avro_lists = chunks(avro_files,chunk_size)

print("number of lists:",len(avro_lists))

class Counter:
    def __init__(self,count=0,log_each=100,total = 0):
        self.count    = count
        self.log_each = log_each
        self.total    = total
    def add(self, c):
        self.count+=c
    def show_completed(self):
        if (self.count % self.log_each) == 0:
            print("%.2f %% completed" % ((self.count/self.total) * 100))
    def __repr__(self):
        return self.count
    
@orch.Async
def map_list_ts_key(file_list, counter):
    local_dates = {}
    for file in file_list:
        num_records = 0
        with open("%s/%s" % (ztf_in,file), 'rb') as fo:
            avro_reader = reader(fo)
            for record in avro_reader:
                #pprint(record)
                num_records+=1
                jd = record["candidate"]["jd"]
                ts = julian.from_jd(jd, fmt='jd')
                ts_key = ts.strftime("%Y%m%d")
                if ts_key in local_dates:
                    local_dates[ts_key]+=1
                else:
                    local_dates[ts_key]=1

        counter.add(num_records)
        counter.show_completed()

    print(len(file_list),local_dates)
    return local_dates

counter = Counter(0,log_each, len(avro_files))

counts = [ Promise.resolve(map_list_ts_key(x,counter)) for x in avro_lists ]

local_dates = []
# wait for the async calls
for x in counts:
    x.get().wait()
    # one get fo the promise, and the other get for the Async call
    local_dates.append(x.get().get())

# putting all local_dates together

def merge(x,y):
    ret={}
    keys = set(list(x.keys()) + list(y.keys()))
    for key in keys:
        if key in ret:
            ret[key]+=(x[key]+y[key])
        else:
            ret[key]=(x[key]+y[key])
    return ret

dates = functools.reduce(merge,local_dates)
print(dates)
# Out:
# chunk_size:  1000
# number of lists: 10
# [<Promise at 0x2af54144d6d8 fulfilled with <orchestrator._async.AsyncCall object at 0x2af59130c0b8>>, <Promise at 0x2af54141c080 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c240>>, <Promise at 0x2af54141c2e8 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c7f0>>, <Promise at 0x2af54141c358 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141ce10>>, <Promise at 0x2af54141c5f8 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141cfd0>>, <Promise at 0x2af54141c5c0 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c550>>, <Promise at 0x2af54141cc50 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c4e0>>, <Promise at 0x2af54141ce48 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c0b8>>, <Promise at 0x2af54141c1d0 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c400>>, <Promise at 0x2af54141c6a0 fulfilled with <orchestrator._async.AsyncCall object at 0x2af54141c208>>]
# 10.00 % completed
# 20.00 % completed
# 30.00 % completed
# 40.00 % completed
# 50.01 % completed
# 60.01 % completed
# 70.01 % completed
# 80.01 % completed
# 90.01 % completed
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 1000 {'20190728': 1000}
# 999 {'20190728': 999}
# {'20190728': 9999}

# %%
# let's try to use different nodes to see if performance can be better

# rebuild the list?
rebuild_avro_list = True
if rebuild_avro_list:
    num_alerts=0

    avro_files = []
    avro_limit = 50000

    for file in os.listdir(ztf_in):
        if file.endswith(".avro"):
            num_alerts+=1
            if num_alerts < avro_limit:
                avro_files.append(file)

    print("num alerts: %d" % num_alerts)

number_of_chunks = 10

chunk_size = int(len(avro_files)/number_of_chunks)+1
print("chunk_size: ",chunk_size)

log_each    = 1000

chunks = lambda l, n: [l[x: x+n] for x in range(0, len(l), n)]
avro_lists = chunks(avro_files,chunk_size)

@orch.Async
def new_map_list_ts_key(file_list):
    
    from fastavro import reader, writer
    import julian
    
    log_each     = 100
    local_dates = {}
    ztf_date     = "20190728"
    ztf_in       = "in/%s" % ztf_date
    num_records  = 0
    for file in file_list:
        with open("%s/%s" % (ztf_in,file), 'rb') as fo:
            avro_reader = reader(fo)
            for record in avro_reader:
                #pprint(record)
                num_records+=1
                jd = record["candidate"]["jd"]
                ts = julian.from_jd(jd, fmt='jd')
                ts_key = ts.strftime("%Y%m%d")
                if ts_key in local_dates:
                    local_dates[ts_key]+=1
                else:
                    local_dates[ts_key]=1
        if num_records % log_each == 0:
            print("%.2f %% completed" % ((num_records/len(file_list)) * 100))
        
    return local_dates

def mapping_job(file_list):
    job=orch.Job(params={\
        "ntasks":"1",
        "nodes":"1",
        "job-name":"avro_map_ts_key",
        "cpus-per-task":"5"
    })
    job.setVerbose(False)
    ret_list = job.run(new_map_list_ts_key, file_list)
    return(ret_list)

res = []
for avro_list in avro_lists:
    # process each list as a promise 
    p = Promise.resolve(mapping_job(avro_list))
    res.append(p)

# gather results
local_dates = Promise.all(res).then(lambda x: functools.reduce(merge,[p.get().get() for p in x]))

# print the result
print(local_dates.get())
# Out:
# num alerts: 125586
# chunk_size:  5000
# {'20190728': 49999}
